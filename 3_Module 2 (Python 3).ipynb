# %% [markdown]
# # Module 2 (Python 3)

# %% [markdown]
# ## Basic NLP Tasks with NLTK

# %%
import nltk

## download this only when for the first time: nltk.download()
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ### Counting vocabulary of words

# %%
text5
# Out:
# <Text: Chat Corpus>

# %%
sent5
# Out:
# ['I',
#  'have',
#  'a',
#  'problem',
#  'with',
#  'people',
#  'PMing',
#  'me',
#  'to',
#  'lol',
#  'JOIN']

# %%
len(sent5)
# Out:
# 11

# %%
len(text5)
# Out:
# 45010

# %% [markdown]
# ### Unique nr of words

# %%
len(set(text5))
# Out:
# 6066

# %%
list(set(text5))[:10] ## TYPE FIRST UNIQUE WORDS. "u" stands for UTP-8 coding
# Out:
# [u'',
#  u'raining',
#  u'fawk',
#  u'four',
#  u'woods',
#  u'hanging',
#  u'Until',
#  u'opener',
#  u'lord',
#  u'minigames']

# %% [markdown]
# ### Frequency of words

# %%
dist = FreqDist(text5) ## FreqDist is a command
len(dist) ## set of UNIQUE WORDS
# Out:
# 6066

# %%
vocab1 = dist.keys() ## the ACTUAL WORDS
#vocab1[:10] 
# In Python 3 dict.keys() returns an iterable view instead of a list
list(vocab1)[:10] ## first 10 words
# Out:
# [u'',
#  u'raining',
#  u'fawk',
#  u'four',
#  u'woods',
#  u'hanging',
#  u'Until',
#  u'opener',
#  u'lord',
#  u'minigames']

# %%
dist['four'] ## give me distribution of word 'four'
# Out:
# 1

# %% [markdown]
# ### how may times words occured with the certain lenth

# %%
freqwords = [w for w in vocab1 if len(w) > 5 and dist[w] > 100] 
freqwords
# Out:
# [u'ACTION']

# %% [markdown]
# ### Normalization and stemming

# %%
input1 = "List listed lists listing listings"
words1 = input1.lower().split(' ')
words1
# Out:
# ['list', 'listed', 'lists', 'listing', 'listings']

# %%
porter = nltk.PorterStemmer()
[porter.stem(t) for t in words1]
# Out:
# [u'list', u'list', u'list', u'list', u'list']

# %% [markdown]
# ### Lemmatization
# Is like Stemming, but keeping words useful / which make sense

# %%
udhr = nltk.corpus.udhr.words('English-Latin1') 
udhr[:20] ##print first 20 words
# Out:
# [u'Universal',
#  u'Declaration',
#  u'of',
#  u'Human',
#  u'Rights',
#  u'Preamble',
#  u'Whereas',
#  u'recognition',
#  u'of',
#  u'the',
#  u'inherent',
#  u'dignity',
#  u'and',
#  u'of',
#  u'the',
#  u'equal',
#  u'and',
#  u'inalienable',
#  u'rights',
#  u'of']

# %%
[porter.stem(t) for t in udhr[:20]] # Still Lemmatization
# Out:
# [u'Univers',
#  u'Declar',
#  u'of',
#  u'Human',
#  u'Right',
#  u'Preambl',
#  u'Wherea',
#  u'recognit',
#  u'of',
#  u'the',
#  u'inher',
#  u'digniti',
#  u'and',
#  u'of',
#  u'the',
#  u'equal',
#  u'and',
#  u'inalien',
#  u'right',
#  u'of']

# %%
WNlemma = nltk.WordNetLemmatizer()
[WNlemma.lemmatize(t) for t in udhr[:20]]
# Out:
# [u'Universal',
#  u'Declaration',
#  u'of',
#  u'Human',
#  u'Rights',
#  u'Preamble',
#  u'Whereas',
#  u'recognition',
#  u'of',
#  u'the',
#  u'inherent',
#  u'dignity',
#  u'and',
#  u'of',
#  u'the',
#  u'equal',
#  u'and',
#  u'inalienable',
#  u'right',
#  u'of']

# %% [markdown]
# ### Tokenization - splitting sentence into the words

# %%
text11 = "Children shouldn't drink a sugary drink before bed."
text11.split(' ')
# Out:
# ['Children', "shouldn't", 'drink', 'a', 'sugary', 'drink', 'before', 'bed.']

# %% [markdown]
# ### NLTK has an in-built tokenizer

# %%
nltk.word_tokenize(text11)
# Out:
# ['Children',
#  'should',
#  "n't",
#  'drink',
#  'a',
#  'sugary',
#  'drink',
#  'before',
#  'bed',
#  '.']

# %% [markdown]
# ### Sentence Splitting: in-built sentence splitter too:

# %%
text12 = "This is the first sentence. A gallon of milk in the U.S. costs $2.99. Is this the third sentence? Yes, it is!"
sentences = nltk.sent_tokenize(text12)
len(sentences)
# Out:
# 4

# %%
sentences
# Out:
# ['This is the first sentence.',
#  'A gallon of milk in the U.S. costs $2.99.',
#  'Is this the third sentence?',
#  'Yes, it is!']

# %% [markdown]
# ## Advanced NLP Tasks with NLTK

# %% [markdown]
# ### POS tagging - Part-of-Speach tagging

# %%
nltk.help.upenn_tagset('MD')
# Out:
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would

# %%
text13 = nltk.word_tokenize(text11)
nltk.pos_tag(text13)
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-22-ba9684e23f62> in <module>()
#       1 text13 = nltk.word_tokenize(text11)
# ----> 2 nltk.pos_tag(text13)
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\__init__.pyc in pos_tag(tokens, tagset)
#     108     :rtype: list(tuple(str, str))
#     109     """
# --> 110     tagger = PerceptronTagger()
#     111     return _pos_tag(tokens, tagset, tagger)
#     112
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\perceptron.pyc in __init__(self, load)
#     139         if load:
#     140             AP_MODEL_LOC = str(find('taggers/averaged_perceptron_tagger/'+PICKLE))
# --> 141             self.load(AP_MODEL_LOC)
#     142
#     143     def tag(self, tokens):
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\perceptron.pyc in load(self, loc)
#     207         '''
#     208
# --> 209         self.model.weights, self.tagdict, self.classes = load(loc)
#     210         self.model.classes = self.classes
#     211
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\data.pyc in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     799
#     800     # Load the resource.
# --> 801     opened_resource = _open(resource_url)
#     802
#     803     if format == 'raw':
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\data.pyc in _open(resource_url)
#     922         return find(path_, ['']).open()
#     923     else:
# --> 924         return urlopen(resource_url)
#     925
#     926 ######################################################################
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in _open(self, req, data)
#     450
#     451         return self._call_chain(self.handle_open, 'unknown',
# --> 452                                 'unknown_open', req)
#     453
#     454     def error(self, proto, *args):
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in unknown_open(self, req)
#    1264     def unknown_open(self, req):
#    1265         type = req.get_type()
# -> 1266         raise URLError('unknown url type: %s' % type)
#    1267
#    1268 def parse_keqv_list(l):
#
# URLError: <urlopen error unknown url type: c>

# %%
text14 = nltk.word_tokenize("Visiting aunts can be a nuisance")
nltk.pos_tag(text14)
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-23-c09a89e97ee9> in <module>()
#       1 text14 = nltk.word_tokenize("Visiting aunts can be a nuisance")
# ----> 2 nltk.pos_tag(text14)
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\__init__.pyc in pos_tag(tokens, tagset)
#     108     :rtype: list(tuple(str, str))
#     109     """
# --> 110     tagger = PerceptronTagger()
#     111     return _pos_tag(tokens, tagset, tagger)
#     112
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\perceptron.pyc in __init__(self, load)
#     139         if load:
#     140             AP_MODEL_LOC = str(find('taggers/averaged_perceptron_tagger/'+PICKLE))
# --> 141             self.load(AP_MODEL_LOC)
#     142
#     143     def tag(self, tokens):
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\perceptron.pyc in load(self, loc)
#     207         '''
#     208
# --> 209         self.model.weights, self.tagdict, self.classes = load(loc)
#     210         self.model.classes = self.classes
#     211
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\data.pyc in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     799
#     800     # Load the resource.
# --> 801     opened_resource = _open(resource_url)
#     802
#     803     if format == 'raw':
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\data.pyc in _open(resource_url)
#     922         return find(path_, ['']).open()
#     923     else:
# --> 924         return urlopen(resource_url)
#     925
#     926 ######################################################################
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in _open(self, req, data)
#     450
#     451         return self._call_chain(self.handle_open, 'unknown',
# --> 452                                 'unknown_open', req)
#     453
#     454     def error(self, proto, *args):
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in unknown_open(self, req)
#    1264     def unknown_open(self, req):
#    1265         type = req.get_type()
# -> 1266         raise URLError('unknown url type: %s' % type)
#    1267
#    1268 def parse_keqv_list(l):
#
# URLError: <urlopen error unknown url type: c>

# %%
# Parsing sentence structure
text15 = nltk.word_tokenize("Alice loves Bob")
grammar = nltk.CFG.fromstring("""
S -> NP VP
VP -> V NP
NP -> 'Alice' | 'Bob'
V -> 'loves'
""")

parser = nltk.ChartParser(grammar)
trees = parser.parse_all(text15)
for tree in trees:
    print(tree)
# Out:
# (S (NP Alice) (VP (V loves) (NP Bob)))

# %%
text16 = nltk.word_tokenize("I saw the man with a telescope")
grammar1 = nltk.data.load('mygrammar.cfg')
grammar1
# Out:
# <Grammar with 13 productions>

# %%
parser = nltk.ChartParser(grammar1)
trees = parser.parse_all(text16)
for tree in trees:
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V saw) (NP (Det the) (N man)))
#     (PP (P with) (NP (Det a) (N telescope)))))
# (S
#   (NP I)
#   (VP
#     (V saw)
#     (NP (Det the) (N man) (PP (P with) (NP (Det a) (N telescope))))))

# %%
from nltk.corpus import treebank
text17 = treebank.parsed_sents('wsj_0001.mrg')[0]
print(text17)
# Out:
# (S
#   (NP-SBJ
#     (NP (NNP Pierre) (NNP Vinken))
#     (, ,)
#     (ADJP (NP (CD 61) (NNS years)) (JJ old))
#     (, ,))
#   (VP
#     (MD will)
#     (VP
#       (VB join)
#       (NP (DT the) (NN board))
#       (PP-CLR (IN as) (NP (DT a) (JJ nonexecutive) (NN director)))
#       (NP-TMP (NNP Nov.) (CD 29))))
#   (. .))

# %% [markdown]
# ### POS tagging and parsing ambiguity

# %%
text18 = nltk.word_tokenize("The old man the boat")
nltk.pos_tag(text18)
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-30-fd75e938d203> in <module>()
#       1 text18 = nltk.word_tokenize("The old man the boat")
# ----> 2 nltk.pos_tag(text18)
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\__init__.pyc in pos_tag(tokens, tagset)
#     108     :rtype: list(tuple(str, str))
#     109     """
# --> 110     tagger = PerceptronTagger()
#     111     return _pos_tag(tokens, tagset, tagger)
#     112
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\perceptron.pyc in __init__(self, load)
#     139         if load:
#     140             AP_MODEL_LOC = str(find('taggers/averaged_perceptron_tagger/'+PICKLE))
# --> 141             self.load(AP_MODEL_LOC)
#     142
#     143     def tag(self, tokens):
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\perceptron.pyc in load(self, loc)
#     207         '''
#     208
# --> 209         self.model.weights, self.tagdict, self.classes = load(loc)
#     210         self.model.classes = self.classes
#     211
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\data.pyc in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     799
#     800     # Load the resource.
# --> 801     opened_resource = _open(resource_url)
#     802
#     803     if format == 'raw':
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\data.pyc in _open(resource_url)
#     922         return find(path_, ['']).open()
#     923     else:
# --> 924         return urlopen(resource_url)
#     925
#     926 ######################################################################
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in _open(self, req, data)
#     450
#     451         return self._call_chain(self.handle_open, 'unknown',
# --> 452                                 'unknown_open', req)
#     453
#     454     def error(self, proto, *args):
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in unknown_open(self, req)
#    1264     def unknown_open(self, req):
#    1265         type = req.get_type()
# -> 1266         raise URLError('unknown url type: %s' % type)
#    1267
#    1268 def parse_keqv_list(l):
#
# URLError: <urlopen error unknown url type: c>

# %%
text19 = nltk.word_tokenize("Colorless green ideas sleep furiously")
nltk.pos_tag(text19)
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-31-396df0f74f3f> in <module>()
#       1 text19 = nltk.word_tokenize("Colorless green ideas sleep furiously")
# ----> 2 nltk.pos_tag(text19)
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\__init__.pyc in pos_tag(tokens, tagset)
#     108     :rtype: list(tuple(str, str))
#     109     """
# --> 110     tagger = PerceptronTagger()
#     111     return _pos_tag(tokens, tagset, tagger)
#     112
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\perceptron.pyc in __init__(self, load)
#     139         if load:
#     140             AP_MODEL_LOC = str(find('taggers/averaged_perceptron_tagger/'+PICKLE))
# --> 141             self.load(AP_MODEL_LOC)
#     142
#     143     def tag(self, tokens):
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\tag\perceptron.pyc in load(self, loc)
#     207         '''
#     208
# --> 209         self.model.weights, self.tagdict, self.classes = load(loc)
#     210         self.model.classes = self.classes
#     211
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\data.pyc in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     799
#     800     # Load the resource.
# --> 801     opened_resource = _open(resource_url)
#     802
#     803     if format == 'raw':
#
# C:\Users\EEyJJ\Anaconda2\lib\site-packages\nltk\data.pyc in _open(resource_url)
#     922         return find(path_, ['']).open()
#     923     else:
# --> 924         return urlopen(resource_url)
#     925
#     926 ######################################################################
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in _open(self, req, data)
#     450
#     451         return self._call_chain(self.handle_open, 'unknown',
# --> 452                                 'unknown_open', req)
#     453
#     454     def error(self, proto, *args):
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# C:\Users\EEyJJ\Anaconda2\lib\urllib2.pyc in unknown_open(self, req)
#    1264     def unknown_open(self, req):
#    1265         type = req.get_type()
# -> 1266         raise URLError('unknown url type: %s' % type)
#    1267
#    1268 def parse_keqv_list(l):
#
# URLError: <urlopen error unknown url type: c>
